# %%
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.optimizers import Adam
from keras.losses import SparseCategoricalCrossentropy
from keras.metrics import SparseCategoricalAccuracy


(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 14s 0us/step

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
x_train

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0


model = Sequential([
    Flatten(input_shape=(32, 32, 3)),
    Dense(256, activation='relu'),
    Dense(256, activation='relu'),
    Dense(10)
])

model.compile(optimizer=Adam(),
              loss=SparseCategoricalCrossentropy(from_logits=True),
              metrics=[SparseCategoricalAccuracy()])
model.fit(x_train, y_train, verbose=1,  validation_data=(x_test, y_test), batch_size=128, epochs=20)
# Out:
# Epoch 1/20
# 391/391 [==============================] - 4s 6ms/step - loss: 1.8772 - sparse_categorical_accuracy: 0.3245 - val_loss: 1.6825 - val_sparse_categorical_accuracy: 0.3980
# Epoch 2/20
# 391/391 [==============================] - 1s 4ms/step - loss: 1.6747 - sparse_categorical_accuracy: 0.4009 - val_loss: 1.6030 - val_sparse_categorical_accuracy: 0.4346
# Epoch 3/20
# 391/391 [==============================] - 2s 4ms/step - loss: 1.5972 - sparse_categorical_accuracy: 0.4276 - val_loss: 1.5555 - val_sparse_categorical_accuracy: 0.4446
# Epoch 4/20
# 391/391 [==============================] - 2s 4ms/step - loss: 1.5382 - sparse_categorical_accuracy: 0.4514 - val_loss: 1.5134 - val_sparse_categorical_accuracy: 0.4612
# Epoch 5/20
# 391/391 [==============================] - 2s 5ms/step - loss: 1.4918 - sparse_categorical_accuracy: 0.4695 - val_loss: 1.5566 - val_sparse_categorical_accuracy: 0.4394
# Epoch 6/20
# ...

# %%
model.evaluate(x_test, y_test, verbose = 1, batch_size=128)
# Out:
# 79/79 [==============================] - 0s 4ms/step - loss: 1.4126 - sparse_categorical_accuracy: 0.5070
# [1.4125564098358154, 0.5070000290870667]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
for i in range(1,10):
  plt.subplot(3,3,i)
  plt.imshow(np.squeeze(x_train[np.random.randint(0, x_test.shape[0]-1, 1), :, :, :]))

plt.show()

# %%
model.save_weights('tamrin1.weights.h5')
